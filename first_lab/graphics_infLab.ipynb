# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy as sp
from math import exp, sin, cos

# %%
y = [0.167187, 0.166992, 0.168408, 0.166577, 0.166101, 0.165637, 0.165866, 0.16593, 0.166102, 0.166608, 0.166553]
x = [5120, 10240, 20480, 40960, 81920, 163840, 327680, 655360, 1310720, 2621440, 5242880]

plt.figure(figsize=(11, 8))
plt.title("Dicrete(1). Шесть возможных состояний(0, 5)", fontsize = 15)
plt.xlabel("test_count", fontsize = 15)
plt.ylabel("p", fontsize = 15)
plt.scatter(x, y)
plt.plot(x, y, label= "p от test_count")
plt.plot(x, [1/6 for elem in x], color='r', label = 'p = 1/6')
plt.legend(loc='upper right', fontsize = 15)

# %%
y = [0.6, 0.55, 0.55, 0.4625, 0.4875, 0.490625, 0.495313, 0.496094, 0.483594, 0.496289, 0.496094, 0.49624, 0.497339, 0.499463, 0.499554, 0.500015, 0.49969, 0.500019, 0.500501, 0.500058]
x = [10, 20, 40, 80, 160, 320, 640, 1280, 2560, 5120, 10240, 20480, 40960, 81920, 163840, 327680, 655360, 1310720, 2621440, 5242880]
plt.figure(figsize=(11, 8))
plt.title("Segment(0, 5). 12 возможных состояний(0, 11)", fontsize = 15)
plt.xlabel("test_count", fontsize = 15)
plt.ylabel("p", fontsize = 15)
plt.scatter(x, y)
plt.plot(x, y, label= "p от test_count")
plt.plot(x, [1/2 for elem in x], color='r', label = 'p = 1/2')
plt.legend(loc='upper right', fontsize = 15)

# %%
y = [0.6, 0.4, 0.5, 0.4875, 0.4875, 0.5, 0.49375, 0.510156, 0.507812, 0.508594, 0.502344, 0.502979, 0.503906, 0.500867, 0.500995, 0.500653, 0.500885, 0.500936, 0.500589, 0.500586]
x = [10, 20, 40, 80, 160, 320, 640, 1280, 2560, 5120, 10240, 20480, 40960, 81920, 163840, 327680, 655360, 1310720, 2621440, 5242880]
plt.figure(figsize=(11, 8))
plt.title("Set(1,3,5, 7, 9, 11). 12 возможных состояний(0, 11)", fontsize = 15)
plt.xlabel("test_count", fontsize = 15)
plt.ylabel("p", fontsize = 15)
plt.scatter(x, y)
plt.plot(x, y, label= "p от test_count")
plt.plot(x, [1/2 for elem in x], color='r', label = 'p = 1/2')
plt.legend(loc='upper right', fontsize = 15)

# %%
y = [0.01971, 0.118597, 0.217489, 0.315964, 0.414897, 0.51459, 0.61288, 0.712507, 0.811747, 0.910759]
x = [1, 11, 21, 31, 41, 51, 61, 71, 81, 91]
plt.figure(figsize=(11, 8))
plt.title("Segment(0, n). 101 возможное состояние(0, 100)", fontsize = 15)
plt.xlabel("Размер промежутка", fontsize = 15)
plt.ylabel("p", fontsize = 15)
plt.scatter(x, y)
plt.plot(x, y, label= "P от размера промежутка")
plt.legend(loc='upper left', fontsize = 15)

# %%
y = [0.109913, 0.109987, 0.109966, 0.110001, 0.110139, 0.11, 0.109988, 0.110088, 0.109893]
x = [1, 11, 21, 31, 41, 51, 61, 71, 81]
plt.figure(figsize=(11, 8))
plt.title("Segment(n, n+10). 101 возможное состояние(0, 100)", fontsize = 15)
plt.xlabel("начало промежутка", fontsize = 15)
plt.ylabel("p", fontsize = 15)
plt.scatter(x, y)
plt.plot(x, y, label= "P от начала промежутка")
plt.plot(x, [11/100 for elem in x], label = 'p = 1/9')
plt.legend(loc='upper left', fontsize = 15)

# %%
x = [0, 10, 20, 30, 40, 50, 60, 70, 80]
y = [0.0600143, 0.0600379, 0.0599674, 0.0599933, 0.0600477, 0.0600209, 0.0599142, 0.0601222, 0.0599825]
plt.figure(figsize=(11, 8))
plt.title("Set(1 + i, 3 + i, 5 + i, 7 + i, 9 + i, 11 + i). 101 возможное состояние(0, 100)", fontsize = 15)
plt.xlabel("Сдвиг (i)", fontsize = 15)
plt.ylabel("p", fontsize = 15)
plt.scatter(x, y)
plt.plot(x, y, label= "P от начала промежутка")
plt.plot(x, [6/100 for elem in x], label = 'p = 6/101')
plt.legend(loc='upper left', fontsize = 15)
